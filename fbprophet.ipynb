# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os,sys
# !pip install httpstan
# !pip install pystan
# !pip install fbprophet
from fbprophet import Prophet
# Out:
# trix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(void)': cannot convert argument 1 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(281): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis'
#           with
#           [
#               F=stan::math::internal::ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): error C2664: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)': cannot convert argument 1 from 'Eigen::VectorXd' to 'const double &'
#           with
#           [
#               F=stan::math::internal::ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: Reason: cannot convert from 'Eigen::VectorXd' to 'const double'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(333): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars'
#           with
#           [
#               F=stan::math::internal::ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/ordered_constrain.hpp(88): error C2440: 'return': cannot convert from 'void' to 'Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/ordered_constrain.hpp(88): note: Expressions of type void cannot be converted to other types
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): error C2664: 'size_t stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory(size_t)': cannot convert argument 2 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(200): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(408): note: while compiling class template member function 'auto stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::operator ()(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(617): note: see reference to class template instantiation 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>' being compiled
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/positive_ordered_constrain.hpp(86): note: see reference to function template instantiation 'auto stan::math::adj_jac_apply<stan::math::internal::positive_ordered_constrain_op,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)' being compiled
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): error C2664: 'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(void)': cannot convert argument 1 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(281): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): error C2664: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)': cannot convert argument 1 from 'Eigen::VectorXd' to 'const double &'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: Reason: cannot convert from 'Eigen::VectorXd' to 'const double'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(333): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars'
#           with
#           [
#               F=stan::math::internal::positive_ordered_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/positive_ordered_constrain.hpp(86): error C2440: 'return': cannot convert from 'void' to 'Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/positive_ordered_constrain.hpp(86): note: Expressions of type void cannot be converted to other types
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): error C2664: 'size_t stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory(size_t)': cannot convert argument 2 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(200): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(408): note: while compiling class template member function 'auto stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::operator ()(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(617): note: see reference to class template instantiation 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>' being compiled
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/simplex_constrain.hpp(97): note: see reference to function template instantiation 'auto stan::math::adj_jac_apply<stan::math::internal::simplex_constrain_op,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)' being compiled
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): error C2664: 'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(void)': cannot convert argument 1 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(281): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): error C2664: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)': cannot convert argument 1 from 'Eigen::VectorXd' to 'const double &'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: Reason: cannot convert from 'Eigen::VectorXd' to 'const double'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(333): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars'
#           with
#           [
#               F=stan::math::internal::simplex_constrain_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/simplex_constrain.hpp(97): error C2440: 'return': cannot convert from 'void' to 'Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/simplex_constrain.hpp(97): note: Expressions of type void cannot be converted to other types
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): error C2664: 'size_t stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory(size_t)': cannot convert argument 2 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(410): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(200): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::count_memory'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(408): note: while compiling class template member function 'auto stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::operator ()(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(617): note: see reference to class template instantiation 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>' being compiled
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/softmax.hpp(78): note: see reference to function template instantiation 'auto stan::math::adj_jac_apply<stan::math::internal::softmax_op,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>(const Eigen::Matrix<stan::math::var,-1,1,0,-1,1> &)' being compiled
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): error C2664: 'void stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis(void)': cannot convert argument 1 from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>> &'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: Reason: cannot convert from 'const Eigen::Matrix<stan::math::var,-1,1,0,-1,1>' to 'const std::vector<stan::math::var,std::allocator<stan::math::var>>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(412): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(281): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::prepare_x_vis'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): error C2664: 'std::vector<stan::math::var,std::allocator<stan::math::var>> stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars(const std::vector<double,std::allocator<double>> &)': cannot convert argument 1 from 'Eigen::VectorXd' to 'const double &'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: Reason: cannot convert from 'Eigen::VectorXd' to 'const double'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(414): note: No user-defined-conversion operator available that can perform this conversion, or the operator cannot be called
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/functor/adj_jac_apply.hpp(333): note: see declaration of 'stan::math::adj_jac_vari<F,Eigen::Matrix<stan::math::var,-1,1,0,-1,1>>::build_return_varis_and_vars'
#           with
#           [
#               F=stan::math::internal::softmax_op
#           ]
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/softmax.hpp(78): error C2440: 'return': cannot convert from 'void' to 'Eigen::Matrix<stan::math::var,-1,1,0,-1,1>'
#   httpstan/lib/stan/lib/stan_math\stan/math/rev/mat/fun/softmax.hpp(78): note: Expressions of type void cannot be converted to other types
#   httpstan/lib/stan/src\stan/services/util/read_dense_inv_metric.hpp(38): warning C4267: 'argument': conversion from 'size_t' to 'int', possible loss of data
#   error: command 'C:\\Program Files (x86)\\Microsoft Visual Studio\\2019\\Community\\VC\\Tools\\MSVC\\14.26.28801\\bin\\HostX86\\x64\\cl.exe' failed with exit status 2
#   ----------------------------------------
#   ERROR: Failed building wheel for httpstan
# ERROR: Could not build wheels for httpstan which use PEP 517 and cannot be installed directly
# Collecting pystan
#   Using cached pystan-3.1.1-py3-none-any.whl (13 kB)
# Collecting clikit<0.7,>=0.6
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# ERROR: Could not find a version that satisfies the requirement httpstan<4.5,>=4.4 (from pystan) (from versions: 0.2.5, 0.3.0, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.7.2, 0.7.3, 0.7.5, 0.7.6, 0.8.0, 0.9.0, 0.10.1)
# ERROR: No matching distribution found for httpstan<4.5,>=4.4 (from pystan)
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
# Requirement already satisfied: Cython>=0.22 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (0.29.21)
# Collecting cmdstanpy==0.9.5
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14
#   Using cached pystan-3.1.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (1.19.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (1.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (3.3.4)
# Collecting LunarCalendar>=0.0.9
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Using cached convertdate-2.3.2-py3-none-any.whl (47 kB)
# Collecting holidays>=0.10.2
#   Using cached holidays-0.11.1-py3-none-any.whl (133 kB)
# Collecting setuptools-git>=1.2
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (2.8.1)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\cools\anaconda3\lib\site-packages (from fbprophet) (4.50.2)
# Collecting clikit<0.7,>=0.6
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Collecting aiohttp<4.0,>=3.6
#   Using cached aiohttp-3.7.4.post0-cp38-cp38-win_amd64.whl (635 kB)
# Collecting pysimdjson<4.0,>=3.2
#   Using cached pysimdjson-3.2.0-cp38-cp38-win_amd64.whl (151 kB)
# ERROR: Could not find a version that satisfies the requirement httpstan<4.5,>=4.4 (from pystan>=2.14->fbprophet) (from versions: 0.2.5, 0.3.0, 0.3.1, 0.4.0, 0.5.0, 0.6.0, 0.7.2, 0.7.3, 0.7.5, 0.7.6, 0.8.0, 0.9.0, 0.10.1)
# ERROR: No matching distribution found for httpstan<4.5,>=4.4 (from pystan>=2.14->fbprophet)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bdaf1f660346> in <module>
#       6 get_ipython().system('pip install pystan')
#       7 get_ipython().system('pip install fbprophet')
# ----> 8 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
fdir = os.path.join(sys.path[0],"data/")
flist = os.listdir(fdir)
DataSet = {}
for file in flist:
    # print(file)
    Coinname = file.replace("coin_", "", 1).replace(".csv","",1)
    # print(Coinname)
    DataSet[Coinname] = pd.read_csv("data/"+file)

# %%
# Show all the available cryptocurrencies
for key in DataSet:
    print(key)
# Out:
# Aave
# BinanceCoin
# Bitcoin
# Cardano
# ChainLink
# Cosmos
# CryptocomCoin
# Dogecoin
# EOS
# Ethereum
# Iota
# Litecoin
# Monero
# NEM
# Polkadot
# Solana
# Stellar
# Tether
# Tron
# Uniswap
# USDCoin
# WrappedBitcoin
# XRP

# %%
coin = "Bitcoin"
df = DataSet[coin]

# %%
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
cols = [3,7]
df = df[df.columns[cols]]
df.columns = ['Date','Close']
df.rename(columns={"Date": "ds", "Close": "y"},inplace=True)
df.head()
# Out:
# C:\Users\cools\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                     ds           y
# 0  2013-04-29 23:59:59  144.539993
# 1  2013-04-30 23:59:59  139.000000
# 2  2013-05-01 23:59:59  116.989998
# 3  2013-05-02 23:59:59  105.209999
# 4  2013-05-03 23:59:59   97.750000

# %%
pd.plotting.register_matplotlib_converters()
plt.figure(figsize=(15,6))
df.set_index('ds').y.plot().figure

# %%
m = Prophet(daily_seasonality=True,seasonality_mode='multiplicative')
m.add_seasonality(name='monthly', period=30.5, fourier_order=5, prior_scale=0.02)
m.fit(df)

# %%
future = m.make_future_dataframe(periods=12, freq ='MS')
future.tail()
# Out:
#                       ds
# 2869 2021-10-01 23:59:59
# 2870 2021-11-01 23:59:59
# 2871 2021-12-01 23:59:59
# 2872 2022-01-01 23:59:59
# 2873 2022-02-01 23:59:59

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head()
# Out:
#                    ds       yhat   yhat_lower   yhat_upper
# 0 2013-04-29 23:59:59  76.545151 -2834.758612  2822.158258
# 1 2013-04-30 23:59:59  78.388354 -2669.370737  2760.262634
# 2 2013-05-01 23:59:59  81.829147 -2699.625788  2901.410307
# 3 2013-05-02 23:59:59  84.404776 -2845.404517  3023.012767
# 4 2013-05-03 23:59:59  87.629558 -2673.393859  2910.196991

# %%
fig1 = m.plot(forecast)
forecast.plot(x='ds',y='yhat',legend=True,label='predictions',figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='ds'>

# %%
fig2 = m.plot_components(forecast)
